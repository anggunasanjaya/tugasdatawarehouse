# %%
import pandas as pd
import sqlite3
import math
import datetime 
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

from IPython.core.display import display, HTML
display(HTML("<style>div.output_scroll { height: 44em; }</style>"))
# Out:
# <style>div.output_scroll { height: 44em; }</style>

# %%
conn = sqlite3.connect('database.db')

# %%
c = conn.cursor()

# %%
df = pd.read_csv("food.csv")
df
# Out:
#     Gender                                       comfort_food  drink  \
# 0        2                                               none    1.0
# 1        1                        chocolate, chips, ice cream    2.0
# 2        1                    frozen yogurt, pizza, fast food    1.0
# 3        1                   Pizza, Mac and cheese, ice cream    2.0
# 4        1                       Ice cream, chocolate, chips     2.0
# 5        1                          Candy, brownies and soda.    2.0
# 6        2       Chocolate, ice cream, french fries, pretzels    1.0
# 7        1                   Ice cream, cheeseburgers, chips.    2.0
# 8        1                           Donuts, ice cream, chips    1.0
# 9        1              Mac and cheese, chocolate, and pasta     1.0
# 10       1  Pasta, grandma homemade chocolate cake anythin...    2.0
# 11       1             chocolate, pasta, soup, chips, popcorn    1.0
# 12       2                        Cookies, popcorn, and chips    2.0
# 13       1                         ice cream, cake, chocolate    2.0
# 14       2    Pizza, fruit, spaghetti, chicken and Potatoes      2.0
# 15       2                        cookies, donuts, candy bars    2.0
# 16       1                       Saltfish, Candy and Kit Kat     1.0
# 17       2                          chips, cookies, ice cream    2.0
# 18       1                               Chocolate, ice crea     1.0
# 19       2                              pizza, wings, Chinese    2.0
# 20       2                             Fast food, pizza, subs    2.0
# 21       2                       chocolate, sweets, ice cream    NaN
# 22       2                            burgers, chips, cookies    1.0
# 23       2                              Chilli, soup, pot pie    1.0
# 24       1                        Soup, pasta, brownies, cake    2.0
# 25       1            chocolate, ice cream/milkshake, cookies    1.0
# 26       2             Chips, ice cream, microwaveable foods     1.0
# 27       2                            Chicken fingers, pizza     2.0
# 28       2                 cookies, hot chocolate, beef jerky    1.0
# 29       2  Tomato soup, pizza, Fritos, Meatball sub, Dr. ...    2.0
#
#                                   food_childhood
# 0                             rice  and chicken
# 1   chicken and biscuits, beef soup, baked beans
# 2                   mac and cheese, pizza, tacos
# 3                  Beef stroganoff, tacos, pizza
# 4                  Pasta, chicken tender, pizza
# 5                  Fries, plaintain & fried fish
# 6                    grilled chicken, hamburgers
# 7        chicken, cheesey potatoes, and hot dogs
# 8                              Shrimp, spaghetti
# 9                         Pasta, Eggs, Pancakes
# 10                                       Chicken
# 11                   Scalloped potatoes and ham
# 12    Pizza, chicken wings, and corn on the cob
# 13                          steak, lasagna, crab
# 14                                         Pizza
# 15                                         pizza
# 16              Curry, Stew Chicken and Saltfish
# 17        chicken fingers, steak, mac and cheese
# 18                                       Chicken
# 19                                     manacotti
# 20                        pizza, chicken fingers
# 21                                         Pasta
# 22                                         pasta
# 23                               Chicken Nuggets
# 24                                    Spaghetti
# 25           Chicken parm, beef stroganof, tacos
# 26                          Chicken Parm, Pizza
# 27                                         Steak
# 28      Deer Steak, Buttered Pasta, Garlic Pasta
# 29      Crab legs, Mushroom soup, homemade rolls
